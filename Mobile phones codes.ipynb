# %%
#Busines Understanding

#Understanding the trends in mobile phones sales over years for making business decisions. This will involve the following

#- Finding the trends in total sales of mobile phones by manufacturers (Questions 1&3)
    
#- Understanding the pattern in sales of different phone types by manufacturers (Question 2)
    
#- examining the changes in the number of phone models launched over years (Question 4 & 5)

#- establishing a relationship between the observed trends

# Direct questions to explore from the data

#1. Find the total number of phones sold by various manufacturers
#3. Which manufacturer sold highest number of Smartphones?
#2. Which manufactural sold highest number of Touchscreen? which sold highest number of bar phones?
#4. In which year was the most phones sold?
#5. In which year was the most phone models launched?

# %%
#Data Understanding

# %%
#Access the data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\debo_\\Desktop\\ProjectsData\\best-selling-mobile-phones.csv")
df
# Out:
#     manufacturer                         model          form smartphone  year  \
# 0          Nokia                          1100           Bar         No  2003
# 1          Nokia                          1110           Bar         No  2005
# 2          Apple    iPhone 6 and iPhone 6 Plus   Touchscreen        Yes  2014
# 3          Nokia        105 (2013), 105 (2015)           Bar         No  2013
# 4          Apple  iPhone 6S and iPhone 6S Plus   Touchscreen        Yes  2015
# ..           ...                           ...           ...        ...   ...
# 106           LG                            G2   Touchscreen        Yes  2013
# 107         LeTV                   LeEco Le 1s   Touchscreen        Yes  2016
# 108       Google            Pixel and Pixel XL   Touchscreen        Yes  2016
# 109         Palm                        Centro  Keyboard bar        Yes  2007
# 110        Nokia                           N97   Tilt slider        Yes  2009
#
#      units_sold_m
# 0           250.0
# 1           247.5
# 2           224.0
# 3           200.0
# 4           174.1
# ..            ...
# 106           3.0
# 107           3.0
# 108           2.1
# 109           2.0
# 110           2.0
#
# [111 rows x 6 columns]

# %%
#Data Exploration

# %%
status_val=df.manufacturer.value_counts()
status_val
# Out:
# Samsung                     35
# Nokia                       27
# Apple                       14
# LG                           7
# Xiaomi                       7
# Huawei                       6
# Motorola                     5
# Sony Ericsson                3
# Oppo                         2
# LeTV                         1
# Google                       1
# Research In Motion (RIM)     1
# Palm                         1
# HTC                          1
# Name: manufacturer, dtype: int64

# %%
status_val1=df.model.value_counts()
status_val1.head(50)
# Out:
# iPhone SE (2nd generation)                        1
# E71                                               1
# 1280                                              1
# Galaxy A01                                        1
# iPhone XR, iPhone XS and iPhone XS Max            1
# Galaxy A10                                        1
# RAZR V3                                           1
# Shine                                             1
# Galaxy A30                                        1
# 3210                                              1
# Galaxy A20                                        1
# Galaxy Note                                       1
# Mi 2                                              1
# E250                                              1
# KP100                                             1
# iPhone                                            1
# E1100                                             1
# Galaxy Note 3                                     1
# iPhone 4S                                         1
# iPhone 8 and iPhone 8 Plus                        1
# Galaxy Note 9                                     1
# Mate 9                                            1
# iPhone 5S                                         1
# LeEco Le 1s                                       1
# iPhone 3GS                                        1
# 1600 (1650/1661)                                  1
# Galaxy S7 and Galaxy S7 edge                      1
# Galaxy S6 and Galaxy S6 edge                      1
# Mate 30 and Mate 30 Pro                           1
# Galaxy Note II                                    1
# 6600                                              1
# iPhone 7 and iPhone 7 Plus                        1
# 3100 (3120)                                       1
# iPhone 6 and iPhone 6 Plus                        1
# Thunderbolt                                       1
# 2600 (2610/2626/2630)                             1
# Galaxy A51                                        1
# Galaxy A30s                                       1
# SGH-E700                                          1
# K750                                              1
# 6230 (6233)                                       1
# Star/Tocco Lite (S5230)                           1
# Cookie (KP500)                                    1
# N-Gage                                            1
# iPhone 11, iPhone 11 Pro and iPhone 11 Pro Max    1
# 2100                                              1
# Droid Bionic                                      1
# Chocolate VX8500                                  1
# 5800 XpressMusic                                  1
# K300 (K310)                                       1
# Name: model, dtype: int64

# %%
df.dtypes
# Out:
# manufacturer     object
# model            object
# form             object
# smartphone       object
# year              int64
# units_sold_m    float64
# dtype: object

# %%
#Provide a set of columns with 0 missing values
no_nulls = set(df.columns[df.isnull().mean()==0])
no_nulls
# Out:
# {'form', 'manufacturer', 'model', 'smartphone', 'units_sold_m', 'year'}

# %%
#Which column has no missing values? Provide a set of column names that have no missing values
np.sum(df.isnull())
# Out:
# manufacturer    0
# model           0
# form            0
# smartphone      0
# year            0
# units_sold_m    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# manufacturer    0
# model           0
# form            0
# smartphone      0
# year            0
# units_sold_m    0
# dtype: int64

# %%
#The data is in good shape, there are 111 rows and 6 columns with no missing value. 
#The Data cleaning stage of the CRISP-DM will be omitted

# %%
#Analysis and Visualization
#Finding the trends in total sales of mobile phones by manufacturers (Questions 1&3)
#Begin to answer Question 1
#Find the total number of phones sold by various manufacturers

# %%
#Sum the units sold by the different manufacturer group and reset the index
df_Manufacturer=df.groupby(['manufacturer'])['units_sold_m'].sum().reset_index()
df_Manufacturer
# Out:
#                 manufacturer  units_sold_m
# 0                      Apple        1541.9
# 1                     Google           2.1
# 2                        HTC          16.0
# 3                     Huawei         113.8
# 4                         LG          92.0
# 5                       LeTV           3.0
# 6                   Motorola         323.0
# 7                      Nokia        2376.5
# 8                       Oppo          16.7
# 9                       Palm           2.0
# 10  Research In Motion (RIM)          15.0
# 11                   Samsung         953.6
# 12             Sony Ericsson          45.0
# 13                    Xiaomi          99.1

# %%
plt.figure(figsize=(10,5))
chart=sns.barplot(x="manufacturer",y="units_sold_m",data=df_Manufacturer)
sns.set_theme(style="whitegrid")
plt.xlabel('Manufacturer', fontsize=18);
plt.ylabel('Total Units Sold (mil)', fontsize=18);
#plt.title('Total Units of Mobile Phones Sold by Manufacturers (1996-2021)', fontsize=18)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right',fontweight='light',
    fontsize=14)

plt.show()

# %%
#Understanding the pattern in sales of different phone types by manufacturers (Question 2)
#Begin to answer question 2
#Which manufactural sold highest number of Touchscreen? which sold highest number of bar phones?

# %%
#Group the data by form and extract all Touchscreen phones
df_form = df.groupby('form')
df_Touchscreen=df_form.get_group('Touchscreen')
df_Touchscreen
# Out:
#     manufacturer                                           model         form  \
# 2          Apple                      iPhone 6 and iPhone 6 Plus  Touchscreen
# 4          Apple                    iPhone 6S and iPhone 6S Plus  Touchscreen
# 5          Apple                                       iPhone 5S  Touchscreen
# 7          Apple                      iPhone 7 and iPhone 7 Plus  Touchscreen
# 8          Apple  iPhone 11, iPhone 11 Pro and iPhone 11 Pro Max  Touchscreen
# ..           ...                                             ...          ...
# 103      Samsung                                     Galaxy A10s  Touchscreen
# 104      Samsung                                     Galaxy A30s  Touchscreen
# 106           LG                                              G2  Touchscreen
# 107         LeTV                                     LeEco Le 1s  Touchscreen
# 108       Google                              Pixel and Pixel XL  Touchscreen
#
#     smartphone  year  units_sold_m
# 2          Yes  2014         224.0
# 4          Yes  2015         174.1
# 5          Yes  2013         164.5
# 7          Yes  2016         159.9
# 8          Yes  2019         159.2
# ..         ...   ...           ...
# 103        Yes  2019           3.9
# 104        Yes  2019           3.4
# 106        Yes  2013           3.0
# 107        Yes  2016           3.0
# 108        Yes  2016           2.1
#
# [70 rows x 6 columns]

# %%
#Sum the units of Touchscreens (df_Touchscreen) sold by the different manufacturer group and set the result to dataframe
df_Touch_sum=df_Touchscreen.groupby(['manufacturer'])['units_sold_m'].sum().reset_index()
df_Touch_sum
# Out:
#    manufacturer  units_sold_m
# 0         Apple        1541.9
# 1        Google           2.1
# 2           HTC          16.0
# 3        Huawei         113.8
# 4            LG          26.0
# 5          LeTV           3.0
# 6      Motorola          13.0
# 7         Nokia         165.0
# 8          Oppo          16.7
# 9       Samsung         763.6
# 10       Xiaomi          99.1

# %%
plt.figure(figsize=(10,5))
chart=sns.barplot(x="manufacturer",y="units_sold_m",data=df_Touch_sum)
sns.set_theme(style="whitegrid")
plt.xlabel('Manufacturer', fontsize=18);
plt.ylabel('Total Units of Touchscreen Sold (mil)', fontsize=18);
#plt.title('Total Units of Touchscreen Phones Sold by Manufacturers (1996-2021)', fontsize=18)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right',fontweight='light',
    fontsize=14)
plt.show()

# %%
#No. 2a. Apple sold highest number of Touchscreens at 1541.9 million

# %%
#Begin to answer No 2b. which sold highest number of bar phones?
#Get all Bar phones from the groupby 'form' above
df_Bar=df_form.get_group('Bar')
df_Bar
# Out:
#                  manufacturer                   model form smartphone  year  \
# 0                       Nokia                    1100  Bar         No  2003
# 1                       Nokia                    1110  Bar         No  2005
# 3                       Nokia  105 (2013), 105 (2015)  Bar         No  2013
# 6                       Nokia                    3210  Bar         No  1999
# 10                      Nokia                    6600  Bar        Yes  2003
# 11                      Nokia                    1200  Bar         No  2007
# 13                    Samsung                   E1100  Bar         No  2009
# 15                      Nokia   2600 (2610/2626/2630)  Bar         No  2004
# 17                      Nokia        1600 (1650/1661)  Bar         No  2005
# 18                      Nokia             3310 (3330)  Bar         No  2000
# 20                      Nokia             1208 (1209)  Bar         No  2007
# 21                      Nokia                    1280  Bar         No  2010
# 22                      Nokia        6010 (6020/6030)  Bar         No  2004
# 25                      Nokia        5130 (5220/5310)  Bar         No  2007
# 29                   Motorola                    C200  Bar         No  2003
# 30                   Motorola                    C139  Bar         No  2005
# 32                      Nokia             3100 (3120)  Bar         No  2003
# 33                      Nokia             6230 (6233)  Bar         No  2004
# 36                      Nokia           N70 (N72/N73)  Bar        Yes  2005
# 42                      Nokia                    6300  Bar         No  2006
# 47                         LG                   KP100  Bar         No  2008
# 59                      Nokia                    2100  Bar         No  2003
# 73              Sony Ericsson             K300 (K310)  Bar         No  2004
# 74              Sony Ericsson                    K750  Bar         No  2005
# 75              Sony Ericsson             W800 (W810)  Bar         No  2006
# 76   Research In Motion (RIM)        BlackBerry Pearl  Bar        Yes  2006
# 100                        LG          Viewty (KU990)  Bar         No  2007
#
#      units_sold_m
# 0           250.0
# 1           247.5
# 3           200.0
# 6           161.0
# 10          150.0
# 11          150.0
# 13          150.0
# 15          135.0
# 17          130.0
# 18          126.0
# 20          100.0
# 21          100.0
# 22           75.0
# 25           65.0
# 29           60.0
# 30           60.0
# 32           50.0
# 33           50.0
# 36           45.0
# 42           47.0
# 47           30.0
# 59           20.0
# 73           15.0
# 74           15.0
# 75           15.0
# 76           15.0
# 100           5.0

# %%
#Sum the units of Bar (df_Bar) sold by the different manufacturer group and reset the indesx
df_Bar_sum=df_Bar.groupby(['manufacturer'])['units_sold_m'].sum().reset_index()
df_Bar_sum
# Out:
#                manufacturer  units_sold_m
# 0                        LG          35.0
# 1                  Motorola         120.0
# 2                     Nokia        2101.5
# 3  Research In Motion (RIM)          15.0
# 4                   Samsung         150.0
# 5             Sony Ericsson          45.0

# %%
plt.figure(figsize=(10,5))
chart=sns.barplot(x="manufacturer",y="units_sold_m",data=df_Bar_sum)
sns.set_theme(style="whitegrid")
plt.xlabel('Manufacturer', fontsize=18);
plt.ylabel('Total Units of Bar Phones Sold (mil)', fontsize=18);
#plt.title('Total Units of Bar Phones Sold by Manufacturers', fontsize=20)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right',fontweight='light',
    fontsize=14)
plt.show()

# %%
#No.2b. Nokia sold highest number of Bar Phones at 2032.84 million

# %%
#Finding the trends in total sales of mobile phones by manufacturers (Questions 1&3)
#Begin to answer question 3. Which manufacturer sold highest number of Smartphones?

# %%
#Group the data by smartphone and extract'YES'
df_smart = df.groupby('smartphone')
df_smart
df_smart_sum=df_smart.get_group('Yes')
df_smart_sum.head(50)
# Out:
#                 manufacturer                                           model  \
# 2                      Apple                      iPhone 6 and iPhone 6 Plus
# 4                      Apple                    iPhone 6S and iPhone 6S Plus
# 5                      Apple                                       iPhone 5S
# 7                      Apple                      iPhone 7 and iPhone 7 Plus
# 8                      Apple  iPhone 11, iPhone 11 Pro and iPhone 11 Pro Max
# 9                      Apple          iPhone XR, iPhone XS and iPhone XS Max
# 10                     Nokia                                            6600
# 12                     Nokia                                            5230
# 14                     Apple                                        iPhone 5
# 19                     Apple                      iPhone 8 and iPhone 8 Plus
# 23                   Samsung              Galaxy S III and Galaxy S III Mini
# 24                   Samsung                                       Galaxy S4
# 26                     Apple                                        iPhone X
# 27                     Apple                                       iPhone 4S
# 31                   Samsung                    Galaxy S7 and Galaxy S7 edge
# 34                     Apple                                        iPhone 4
# 35                   Samsung                    Galaxy S6 and Galaxy S6 edge
# 36                     Nokia                                   N70 (N72/N73)
# 37                   Samsung                        Galaxy S8 and Galaxy S8+
# 38                   Samsung                                     Galaxy S II
# 39                   Samsung         Galaxy S10, Galaxy S10+ and Galaxy S10e
# 40                   Samsung                        Galaxy S9 and Galaxy S9+
# 43                     Apple                                      iPhone 3GS
# 44                    Huawei                       P20, P20 Pro and P20 Lite
# 45                   Samsung                                      Galaxy A10
# 48                   Samsung                                  Galaxy Note II
# 50                    Xiaomi               Redmi Note 8 and Redmi Note 8 Pro
# 51                   Samsung    Galaxy S20, Galaxy S20+ and Galaxy S20 Ultra
# 52                   Samsung                                        Galaxy S
# 53                   Samsung                         Galaxy Grand Prime Plus
# 54                   Samsung                                      Galaxy A50
# 55                     Apple                      iPhone SE (2nd generation)
# 56                   Samsung                                      Galaxy A51
# 57                   Samsung                                      Galaxy A20
# 60                    Xiaomi               Redmi Note 7 and Redmi Note 7 Pro
# 61                    Huawei                                 P30 and P30 Pro
# 62                   Samsung                                     Galaxy A21s
# 63                    Huawei                         Mate 10 and Mate 10 Pro
# 64                    Huawei                         Mate 20 and Mate 20 Pro
# 65                   Samsung                                      Galaxy A01
# 66                       HTC                                     Thunderbolt
# 67                    Huawei                                          Mate 9
# 68                   Samsung                                      Galaxy A11
# 69                   Samsung                                  Galaxy J2 Core
# 71                     Nokia                                5800 XpressMusic
# 72                     Nokia                                             E71
# 76  Research In Motion (RIM)                                BlackBerry Pearl
# 77                    Xiaomi                                Redmi Note 9 Pro
# 78                   Samsung    Galaxy S21, Galaxy S21+ and Galaxy S21 Ultra
# 79                  Motorola                                    Droid Bionic
#
#             form smartphone  year  units_sold_m
# 2    Touchscreen        Yes  2014         224.0
# 4    Touchscreen        Yes  2015         174.1
# 5    Touchscreen        Yes  2013         164.5
# 7    Touchscreen        Yes  2016         159.9
# 8    Touchscreen        Yes  2019         159.2
# 9    Touchscreen        Yes  2018         151.1
# 10           Bar        Yes  2003         150.0
# 12   Touchscreen        Yes  2009         150.0
# 14   Touchscreen        Yes  2012         146.2
# 19   Touchscreen        Yes  2017         124.7
# 23   Touchscreen        Yes  2012          70.0
# 24   Touchscreen        Yes  2013          70.0
# 26   Touchscreen        Yes  2017          63.0
# 27   Touchscreen        Yes  2011          60.0
# 31   Touchscreen        Yes  2016          55.0
# 34   Touchscreen        Yes  2010          50.0
# 35   Touchscreen        Yes  2015          45.0
# 36           Bar        Yes  2005          45.0
# 37   Touchscreen        Yes  2017          41.0
# 38   Touchscreen        Yes  2011          40.0
# 39   Touchscreen        Yes  2019          37.0
# 40   Touchscreen        Yes  2018          35.4
# 43   Touchscreen        Yes  2009          35.0
# 44   Touchscreen        Yes  2018          32.0
# 45   Touchscreen        Yes  2019          30.3
# 48   Touchscreen        Yes  2012          30.0
# 50   Touchscreen        Yes  2019          30.0
# 51   Touchscreen        Yes  2020          28.0
# 52   Touchscreen        Yes  2010          25.0
# 53   Touchscreen        Yes  2016          24.2
# 54   Touchscreen        Yes  2019          24.2
# 55   Touchscreen        Yes  2020          24.2
# 56   Touchscreen        Yes  2019          23.2
# 57   Touchscreen        Yes  2019          23.1
# 60   Touchscreen        Yes  2019          20.0
# 61   Touchscreen        Yes  2019          20.0
# 62   Touchscreen        Yes  2020          19.4
# 63   Touchscreen        Yes  2017          17.0
# 64   Touchscreen        Yes  2018          17.0
# 65   Touchscreen        Yes  2019          16.9
# 66   Touchscreen        Yes  2011          16.0
# 67   Touchscreen        Yes  2016          15.8
# 68   Touchscreen        Yes  2020          15.3
# 69   Touchscreen        Yes  2018          15.2
# 71   Touchscreen        Yes  2008          15.0
# 72  Keyboard bar        Yes  2008          15.0
# 76           Bar        Yes  2006          15.0
# 77   Touchscreen        Yes  2020          15.0
# 78   Touchscreen        Yes  2021          13.5
# 79   Touchscreen        Yes  2011          13.0

# %%
#Sum the the units_sold in the smartphones dataframe by manufacturer
df_smart_sum_manu = df_smart_sum.groupby(['manufacturer'])['units_sold_m'].sum().reset_index()
df_smart_sum_manu_sort = df_smart_sum_manu.sort_values(['units_sold_m'], ascending=[0])
print(df_smart_sum_manu_sort)
# Out:
#                 manufacturer  units_sold_m
# 0                      Apple        1541.9
# 11                   Samsung         753.6
# 7                      Nokia         390.0
# 3                     Huawei         113.8
# 12                    Xiaomi          99.1
# 8                       Oppo          16.7
# 2                        HTC          16.0
# 10  Research In Motion (RIM)          15.0
# 4                         LG          13.0
# 6                   Motorola          13.0
# 5                       LeTV           3.0
# 1                     Google           2.1
# 9                       Palm           2.0

# %%
plt.figure(figsize=(10,5))
chart=sns.barplot(x="manufacturer",y="units_sold_m",data=df_smart_sum_manu)
sns.set_theme(style="whitegrid")
plt.xlabel('Manufacturer', fontsize=18);
plt.ylabel('Total Units of Smartphones Sold (mil)', fontsize=18);
#plt.title('Total Units of Smartphones Sold by Manufacturers', fontsize=20)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right',fontweight='light',
    fontsize=14)
plt.show()

# %%
#Apple sold the highest number of smartphones at 1541.9 million

# %%
#Examining the changes in the number of phone models launched over years (Question 4 & 5)
#Begin to answer question 4
#In which year was the most phones sold?
#Group the data by year and sum the units sold
df_year = df.groupby(['year'])['units_sold_m'].sum().reset_index()
print(df_year)
# Out:
#     year  units_sold_m
# 0   1996          60.0
# 1   1999         161.0
# 2   2000         126.0
# 3   2003         543.0
# 4   2004         440.0
# 5   2005         497.5
# 6   2006         158.0
# 7   2007         353.0
# 8   2008          70.0
# 9   2009         360.0
# 10  2010         175.0
# 11  2011         139.0
# 12  2012         256.2
# 13  2013         447.5
# 14  2014         238.5
# 15  2015         219.1
# 16  2016         267.0
# 17  2017         255.7
# 18  2018         271.6
# 19  2019         446.2
# 20  2020         101.9
# 21  2021          13.5

# %%
#sort the rows in ascending
df_year_sort = df_year.sort_values(['units_sold_m'], ascending=[0])
df_year_sort
# Out:
#     year  units_sold_m
# 3   2003         543.0
# 5   2005         497.5
# 13  2013         447.5
# 19  2019         446.2
# 4   2004         440.0
# 9   2009         360.0
# 7   2007         353.0
# 18  2018         271.6
# 16  2016         267.0
# 12  2012         256.2
# 17  2017         255.7
# 14  2014         238.5
# 15  2015         219.1
# 10  2010         175.0
# 1   1999         161.0
# 6   2006         158.0
# 11  2011         139.0
# 2   2000         126.0
# 20  2020         101.9
# 8   2008          70.0
# 0   1996          60.0
# 21  2021          13.5

# %%
#No.3. Most phones were sold in 2003

# %%
plt.figure(figsize=(10,5))
chart=sns.barplot(x="year",y="units_sold_m",data=df_year_sort)
sns.set_theme(style="whitegrid")
plt.xlabel('Year', fontsize=18);
plt.ylabel('Total Units of Phones Sold (mil)', fontsize=18);
#plt.title('Total Units of Phones Sold by Year', fontsize=20)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right',fontweight='light',
    fontsize=14)
plt.show()

# %%
#Examining the changes in the number of phone models launched over years (Question 4 & 5)
#Begin to answer question5.
#5. In which year was the most phone models launched?
#Group the data by year and model, then count the models
df_most_model=df.groupby(['year', 'model']).agg(model_count = ('model', 'count'))
df_most_model.head(50)
# Out:
#                               model_count
# year model
# 1996 StarTAC                            1
# 1999 3210                               1
# 2000 3310 (3330)                        1
# 2003 1100                               1
#      2100                               1
#      3100 (3120)                        1
#      6600                               1
#      C200                               1
#      N-Gage                             1
#      SGH-E700                           1
# 2004 2600 (2610/2626/2630)              1
#      2650                               1
#      6010 (6020/6030)                   1
#      6230 (6233)                        1
#      K300 (K310)                        1
#      RAZR V3                            1
# 2005 1110                               1
#      1600 (1650/1661)                   1
#      C139                               1
#      K750                               1
#      N70 (N72/N73)                      1
# 2006 5200 (5300)                        1
#      6300                               1
#      BlackBerry Pearl                   1
#      Chocolate VX8500                   1
#      E250                               1
#      W800 (W810)                        1
# 2007 1200                               1
#      1208 (1209)                        1
#      5130 (5220/5310)                   1
#      5610 XpressMusic                   1
#      Centro                             1
#      N95                                1
#      Viewty (KU990)                     1
#      iPhone                             1
# 2008 5800 XpressMusic                   1
#      E71                                1
#      KP100                              1
#      Shine                              1
# 2009 5230                               1
#      Cookie (KP500)                     1
#      E1100                              1
#      N97                                1
#      Star/Tocco Lite (S5230)            1
#      iPhone 3GS                         1
# 2010 1280                               1
#      Galaxy S                           1
#      iPhone 4                           1
# 2011 Droid Bionic                       1
#      Galaxy Note                        1

# %%
#Compute the sum of model_count for each year
df_mm_count = df_most_model.groupby(['year'])['model_count'].sum().reset_index()
df_mm_count
# Out:
#     year  model_count
# 0   1996            1
# 1   1999            1
# 2   2000            1
# 3   2003            7
# 4   2004            6
# 5   2005            5
# 6   2006            6
# 7   2007            8
# 8   2008            4
# 9   2009            6
# 10  2010            3
# 11  2011            5
# 12  2012            4
# 13  2013            5
# 14  2014            3
# 15  2015            2
# 16  2016            7
# 17  2017            5
# 18  2018            8
# 19  2019           18
# 20  2020            5
# 21  2021            1

# %%
df_mm_count.model_count.max()
# Out:
# 18

# %%
plt.figure(figsize=(10,5))
chart=sns.barplot(x="year",y="model_count",data=df_mm_count)
sns.set_theme(style="whitegrid")
plt.xlabel('Year', fontsize=18);
plt.ylabel('Total Models of Phones Launched', fontsize=18);
#plt.title('Total Models of Phones Sold by Year', fontsize=20)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right',fontweight='light',
    fontsize=14)
plt.show()

# %%
#Most phone models were launched in 2019 with a total of 18 models
